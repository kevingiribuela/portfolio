# %% [markdown]
# # <u> Definición de muestras y coeficientes pre y post cuantización <u>

# %% [markdown]
# ## Generación de muestras y cuantización

# %%
import matplotlib.pyplot as plt
import numpy as np
from tool._fixedInt import *
from random import *

show_plots = 1

# Generación de muestras de entrada aleatorias en 0 y 1
real = []
imag = []
for i in range(0,29):
    real.append(random())
    imag.append(random())

n = np.arange(0,len(real))

# NB_INT  -> Número de bits de la parte entera
# NB_FRAC -> Número de bits de la parte fraccional
NB_INT = 16
NB_FRAC = 15

real_array = arrayFixedInt(NB_INT, NB_FRAC, real)
imag_array = arrayFixedInt(NB_INT, NB_FRAC, imag)

real_fixed = [i.fValue for i in real_array]
imag_fixed = [i.fValue for i in imag_array]

if show_plots:
    plt.figure(figsize = (15,4))
    plt.subplot(1,2,1)
    plt.stem(n,real, basefmt= " ");
    plt.grid(True);
    plt.title("Parte real NO cuantizada", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$Real$", fontsize=14);
    plt.subplot(1,2,2)
    plt.stem(n,imag, basefmt= " ");
    plt.grid(True);
    plt.title("Parte imag NO cuantizada", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$Imag$", fontsize=14);
    
    plt.figure(figsize = (15,4))
    plt.subplot(1,2,1)
    plt.stem(n,real_fixed, basefmt= " ");
    plt.grid(True);
    plt.title("Parte real cuantizada", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$Real$", fontsize=14);
    plt.subplot(1,2,2)
    plt.stem(n,imag_fixed, basefmt= " ");
    plt.grid(True);
    plt.title("Parte imag cuantizada", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$Imag$", fontsize=14);

    # Calculo del error porcentual en la cuantización
    real_error = np.divide(np.subtract(real, real_fixed), real, where=real!=0)*100
    imag_error = np.divide(np.subtract(imag, imag_fixed), imag, where=imag!=0)*100
    
    plt.figure(figsize = (15,4))
    plt.subplot(1,2,1)
    plt.stem(n,real_error, basefmt= " ");
    plt.grid(True);
    plt.title("Error de cuantizacion % - REAL", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$[\%]$", fontsize=14);
    plt.subplot(1,2,2)
    plt.stem(n,imag_error, basefmt= " ");
    plt.grid(True);
    plt.title("Error de cuantizacion % - IMAG", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$[\%]$", fontsize=14);

# %% [markdown]
# ## Generación de coeficientes de filtro IIR y PI

# %%
a_float = [0.51, 0.249]
a_coef  = arrayFixedInt(NB_INT, NB_FRAC, a_float)
a = [i.fValue for i in a_coef]
Na = np.arange(0,len(a_float))

b_float = [0.21, 0.339, 0.12]
b_coef  = arrayFixedInt(NB_INT, NB_FRAC, b_float)
b = [i.fValue for i in b_coef]
Nb = np.arange(0,len(b_float))

Kp_float = 0.21
Kp_fixed = DeFixedInt(NB_INT, NB_FRAC)
Kp_fixed.value = Kp_float
Kp = Kp_fixed.fValue

Ki_float = 0.36
Ki_fixed = DeFixedInt(NB_INT, NB_FRAC)
Ki_fixed.value = Ki_float
Ki = Ki_fixed.fValue


if show_plots:
    plt.figure(figsize = (15,4))
    plt.subplot(1,2,1)
    plt.stem(Na, a_float, basefmt= " ");
    plt.grid(True);
    plt.title("a coefs NO cuantizados", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14);
    plt.subplot(1,2,2)
    plt.stem(Nb, b_float, basefmt= " ");
    plt.grid(True);
    plt.title("b coefs NO cuantizados", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14);

    plt.figure(figsize = (15,4))
    plt.subplot(1,2,1)
    plt.stem(Na, a, basefmt= " ");
    plt.grid(True);
    plt.title("a coefs cuantizados", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14);
    plt.subplot(1,2,2)
    plt.stem(Nb, b, basefmt= " ");
    plt.grid(True);
    plt.title("b coefs cuantizados", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14);

    # Calculo del error porcentual en la cuantización
    a_error = np.divide(np.subtract(a_float, a), a_float, where=a_float!=0)*100
    b_error = np.divide(np.subtract(b_float, b), b_float, where=b_float!=0)*100

    plt.figure(figsize = (15,4))
    plt.subplot(1,2,1)
    plt.stem(Na, a_error, basefmt= " ");
    plt.grid(True);
    plt.title("Error de cuantizacion A %", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$[\%]$", fontsize=14);
    plt.subplot(1,2,2)
    plt.stem(Nb, b_error, basefmt= " ");
    plt.grid(True);
    plt.title("Error de cuantizacion B %", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$[\%]$", fontsize=14);

# %% [markdown]
# # <u> Generación de funciones de filtrado <u>

# %% [markdown]
# ## Creacion de función de filtro IIR

# %%
def iir (x, y):
    partial_prod_B = [DeFixedInt(NB_INT, NB_FRAC), DeFixedInt(NB_INT, NB_FRAC), DeFixedInt(NB_INT, NB_FRAC)]
    partial_sum_B  = [DeFixedInt(NB_INT, NB_FRAC), DeFixedInt(NB_INT, NB_FRAC)]

    partial_prod_A = [DeFixedInt(NB_INT, NB_FRAC), DeFixedInt(NB_INT, NB_FRAC)]
    partial_sum_A  = [DeFixedInt(NB_INT, NB_FRAC), DeFixedInt(NB_INT, NB_FRAC)]
    
    # Forward
    partial_prod_B[0].value = b[0]*x[0]
    partial_prod_B[1].value = b[1]*x[1]
    partial_prod_B[2].value = b[2]*x[2]
    
    partial_sum_B[1].value  = partial_prod_B[2].fValue + partial_prod_B[1].fValue
    partial_sum_B[0].value  = partial_prod_B[0].fValue + partial_sum_B[1].fValue
    
    # Feedback
    partial_prod_A[1].value = -a[1]*y[2]
    partial_prod_A[0].value = -a[0]*y[1]
    
    partial_sum_A[1].value  = partial_prod_A[0].fValue + partial_prod_A[1].fValue
    partial_sum_A[0].value  = partial_sum_A[1].fValue  + partial_sum_B[0].fValue
    
    y[0] = partial_sum_A[0].fValue
    return y[0]

# %% [markdown]
# ## Creación de filtro PI

# %%
def PI_filter(x,y):
    partial_prod = [DeFixedInt(NB_INT, NB_FRAC), DeFixedInt(NB_INT, NB_FRAC)]
    partial_sum  = [DeFixedInt(NB_INT, NB_FRAC), DeFixedInt(NB_INT, NB_FRAC)]
    
    # Forward
    partial_prod[0].value = (Ki- Kp)*x[0]
    partial_prod[1].value = Kp*x[1]

    partial_sum[0].value  = partial_prod[0].fValue + partial_prod[1].fValue
    
    # Feedback
    partial_sum[1].value  = partial_sum[0].fValue  + y[1]
    
    return partial_sum[1].fValue

# %% [markdown]
# ## Creación de operador partel real

# %%
def real_part(x):
    x_in = [DeFixedInt(NB_INT, NB_FRAC), DeFixedInt(NB_INT, NB_FRAC), DeFixedInt(NB_INT, NB_FRAC)]
    out  = DeFixedInt(NB_INT, NB_FRAC)
    x_in[0].value = x[0]
    x_in[1].value = x[1]
    x_in[2].value = x[2]
    
    out.value = x_in[0].fValue + x_in[2].fValue
    return out.fValue

# %% [markdown]
# # <u> Filtrado <u>

# %%
out1 = []
out2 = []
x_shiftreg_real = [0, 0, 0]
y_shiftreg_real = [0, 0, 0]

x_shiftreg_imag = [0, 0, 0]
y_shiftreg_imag = [0, 0, 0]

aux1_real = 0
aux2_real = 0

aux1_imag = 0
aux2_imag = 0

PI_in  = [0, 0]
PI_out = [0, 0]
PI     = DeFixedInt(NB_INT, NB_FRAC)
phase  = []

INITIAL_CONDITION = 
accum_real = DeFixedInt(NB_INT, NB_FRAC)
accum_imag = DeFixedInt(NB_INT, NB_FRAC)

accum_real.value = INITIAL_CONDITION
accum_imag.value = INITIAL_CONDITION

temp_real = DeFixedInt(NB_INT, NB_FRAC)
temp_imag = DeFixedInt(NB_INT, NB_FRAC)

temp_real.value = INITIAL_CONDITION
temp_imag.value = INITIAL_CONDITION
aux_PI = 0

for i,v in enumerate(real_fixed):
    # ******************* Filter REAL *******************
    y_real = iir(x_shiftreg_real, y_shiftreg_real)
    
    # X shiftreg_real
    aux1_real = x_shiftreg_real[0]
    aux2_real = x_shiftreg_real[1]
    x_shiftreg_real[0] = real_fixed[i]
    x_shiftreg_real[1] = aux1_real
    x_shiftreg_real[2] = aux2_real
    
    # Y shiftreg_real
    aux1_real = y_shiftreg_real[0]
    aux2_real = y_shiftreg_real[1]
    y_shiftreg_real[0] = y_real
    y_shiftreg_real[1] = aux1_real
    y_shiftreg_real[2] = aux2_real
    out1.append(y_real)
    
    # ******************* Filter IMAG *******************
    y_imag = iir(x_shiftreg_imag, y_shiftreg_imag)
    
    # X shiftreg_real
    aux1_imag = x_shiftreg_real[0]
    aux2_imag = x_shiftreg_real[1]
    x_shiftreg_real[0] = real_fixed[i]
    x_shiftreg_real[1] = aux1_imag
    x_shiftreg_real[2] = aux2_imag
    
    # Y shiftreg_real
    aux1_imag = y_shiftreg_imag[0]
    aux2_imag = y_shiftreg_imag[1]
    y_shiftreg_imag[0] = y_imag
    y_shiftreg_imag[1] = aux1_imag
    y_shiftreg_imag[2] = aux2_imag
    out2.append(y_imag) 
    
    # ******************* Real part operator *******************
    y1 = real_part(x1_shiftreg)
    y2 = real_part(x2_shiftreg)
    
    # ******************* Filter PI *******************
    PI.value = y1 - y2
    aux_PI   = PI_in[0]
    PI_in[0].fValue = PI.fValue
    PI_in[1].fValue = aux_PI
    
    aux_PI = PI_out[0]
    PI_out[0] = PI_filter(PI_in, PI_out)
    
    PI_out[1] = aux_PI
    
    phase.append(PI_out[0])
    
    # ******************* Acummulator *******************
    accum_real.value = PI_out[0] + accum_real.fValue
    accum_imag.value = PI_out[0] + accum_real.fValue

# %%
for i,v in enumerate(real_fixed):
    
if show_plots:
    n = np.arange(0,len(out1))
    plt.figure(figsize = (15,4))

    plt.subplot(1,2,1)
    plt.stem(n,out1, basefmt= " ");
    plt.grid(True);
    plt.title("Salida del filtro IIR1 cuantizada", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$y[n]$", fontsize=14);

    plt.subplot(1,2,2)
    plt.stem(n,out2, basefmt= " ");
    plt.grid(True);
    plt.title("Salida del filtro IIR2 cuantizada", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$y[n]$", fontsize=14);

# %% [markdown]
# ## Operación de parte real en ambas salida de filtros

# %%
PI_in  = []
PI     = DeFixedInt(NB_INT, NB_FRAC)
x1_shiftreg = [out1[0], 0, 0]
x2_shiftreg = [out2[0], 0, 0]
aux1   = 0
aux2   = 0

for i,v in enumerate(out1):
    # Shiftregister for real part operator
    x1_shiftreg[0] = out1[i]
    x1_shiftreg[1] = aux1
    x1_shiftreg[2] = aux2
    
    x2_shiftreg[0] = out2[i]
    x2_shiftreg[1] = aux1
    x2_shiftreg[2] = aux2
    
    
    # Real part operator
    y1 = real_part(x1_shiftreg)
    y2 = real_part(x2_shiftreg)
    
    PI.value = y1 - y2
    PI_in.append(PI.fValue)

if show_plots:
    plt.figure(figsize = (15,4))
    plt.stem(n,PI_in, basefmt= " ");
    plt.grid(True);
    plt.title("Salida del operadora Real{*} cuantizada", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$PI_{in}[n]$", fontsize=14);

# %% [markdown]
# # Entrada al PI, procesamiento y salida

# %% [markdown]
# ## PI filter generation

# %% [markdown]
# ## PI filtering

# %%
PI_out = []
x_shiftreg = [0, 0]
y_shiftreg = [0, 0]
aux1 = 0
for i,v in enumerate(PI_in):
    # X shiftreg
    aux1 = x_shiftreg[0]
    aux2 = x_shiftreg[1]
    x_shiftreg[0] = PI_in[i]
    x_shiftreg[1] = aux1
    
    # Filter
    y = PI_filter(x_shiftreg, y_shiftreg)
    
    # Y shiftreg
    aux1 = y_shiftreg[0]
    aux2 = y_shiftreg[1]
    y_shiftreg[0] = y
    y_shiftreg[1] = aux1

    PI_out.append(y)

if show_plots:
    plt.figure(figsize = (15,4))
    plt.stem(n,PI_out, basefmt= " ");
    plt.grid(True);
    plt.title("Salida cuantizada del filtro PI", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$PI_{out}[n]$", fontsize=14);

# %% [markdown]
# ## Acumulador

# %%
partial_sum = DeFixedInt(NB_INT, NB_FRAC)
shift_out   = 0
phase_out   = arrayFixedInt(NB_INT, NB_FRAC, PI_out)

for i,v in enumerate(PI_out):
    phase_in = PI_out[i]
    partial_sum.value = phase_in + shift_out
    shift_out = phase_in
    
    phase_out[i].value = partial_sum.fValue 
    
salida = [a.fValue for a in phase_out]

if show_plots:
    plt.figure(figsize = (15,4))
    plt.stem(n,salida, basefmt= " ");
    plt.grid(True);
    plt.title("Correccion de fase", fontweight="bold", fontsize=14);
    plt.xlabel("n", fontsize=14); plt.ylabel("$Phase_{out}[n]$", fontsize=14);
    plt.show()


print("Valores de salida para testear:")
for a in phase_out:
    print(f"{a.__hex__()}")

print("\n\nValores de parte REAL para testear:")
for a in real_array:
    print(f"{a.__hex__()}")
    
print("\n\nValores de parte IMAG para testear:")
for a in imag_array:
    print(f"{a.__hex__()}")
    
print("\n\nValores de parte Kp para testear:")
print(Kp_fixed.__hex__())
print("\n\nValores de parte Ki para testear:")
print(Ki_fixed.__hex__())

print("\n\nValores de A para testear:")
for a in a_coef:
    print(a.__hex__())

print("\n\nValores de B para testear:")
for b in b_coef:
    print(b.__hex__())
# Out:
# Valores de salida para testear:
# 0x0000
# 0x0135
# 0x01D2
# 0xFB7A
# 0xF4ED
# 0xF817
# 0xFDEF
# 0x03A1
# 0x0915
# 0x0BB0
# 0x10AD
# 0x16F4
# 0x190C
# 0x1F01
# 0x2BA2
# 0x3350
# 0x35B4
# 0x384D
# 0x3778
# 0x3206
# 0x306A
# 0x3437
# 0x369A
# 0x3608
# 0x3148
# 0x28BF
# 0x21A5
# 0x1D89
# 0x1C3D
#
#
# Valores de parte REAL para testear:
# 0x267F
# 0x16EB
# 0x2AD7
# 0x5F0A
# 0x4B06
# 0x6173
# 0x6ABC
# 0x5CF5
# 0x338C
# 0x55C8
# 0x2DBC
# 0x78DE
# 0x7EF2
# 0x4AAF
# 0x4695
# 0x2B8A
# 0x1266
# 0x3276
# 0x0B61
# 0x3E2D
# 0x55BD
# 0x5143
# 0x24E9
# 0x394C
# 0x438A
# 0x47BA
# 0x096A
# 0x0E6D
# 0x11EF
#
#
# Valores de parte IMAG para testear:
# 0x0029
# 0x6353
# 0x66D2
# 0x221A
# 0x5350
# 0x0BC2
# 0x599B
# 0x44D5
# 0x190E
# 0x03BB
# 0x5668
# 0x2BF6
# 0x245E
# 0x12D1
# 0x3D6C
# 0x0190
# 0x2173
# 0x6076
# 0x1D3C
# 0x0BB3
# 0x62C6
# 0x2DDD
# 0x6064
# 0x6CD2
# 0x7C6D
# 0x6BCC
# 0x0B23
# 0x192A
# 0x3BDD
#
#
# Valores de parte Kp para testear:
# 0x1AE1
#
#
# Valores de parte Ki para testear:
# 0x2E14
# ...
